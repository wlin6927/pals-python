# %%
import json
import yaml

from pals import MagneticMultipoleParameters, BendParameters
from pals import Drift
from pals import Quadrupole
from pals import BeamLine
from pals import Kicker
from pals import SBend, RBend
from pals import Sextupole

# %%
import math

# %%
# ?BendParameters
# Out:
# Init signature:
# BendParameters(
#     *,
#     rho_ref: float = 0.0,
#     bend_field_ref: float = 0.0,
#     e1: float = 0.0,
#     e2: float = 0.0,
#     e1_rect: float = 0.0,
#     e2_rect: float = 0.0,
#     edge_int1: float = 0.0,
#     edge_int2: float = 0.0,
#     g_ref: float = 0.0,
#     h1: float = 0.0,
#     h2: float = 0.0,
#     L_chord: float = 0.0,
#     L_sagitta: float = 0.0,
#     tilt_ref: float = 0.0,
# ) -> None
# Docstring:      Bend parameters
# Init docstring:
# Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`ValidationError`][pydantic_core.ValidationError] if the input data cannot be
# validated to form a valid model.
#
# `self` is explicitly positional-only to allow `self` as a field name.
# File:           ~/Documents/PALS/pals-python/src/pals/parameters/BendParameters.py
# Type:           ModelMetaclass
# Subclasses:

# %%
# ?MagneticMultipoleParameters
# Out:
# Init signature: MagneticMultipoleParameters(**extra_data: Any) -> None
# Docstring:
# Magnetic multipole parameters
#
# Valid parameter formats:
# - tiltN: Tilt of Nth order multipole
# - BnN: Normal component of Nth order multipole
# - BsN: Skew component of Nth order multipole
# - KnN: Normalized normal component of Nth order multipole
# - KsN: Normalized skew component of Nth order multipole
# - *NL: Length-integrated versions of components (e.g., Bn3L, KsNL)
#
# Where N is a positive integer without leading zeros (except "0" itself).
# Init docstring:
# Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`ValidationError`][pydantic_core.ValidationError] if the input data cannot be
# validated to form a valid model.
#
# `self` is explicitly positional-only to allow `self` as a field name.
# File:           ~/Documents/PALS/pals-python/src/pals/parameters/MagneticMultipoleParameters.py
# Type:           ModelMetaclass
# Subclasses:

# %%
drift1 = Drift(
        name="drift1",
        length=0.25,
    )

# %%
sbend = SBend(
        name = "sb",
        length = 5.0,
        BendP=BendParameters(
            rho_ref=math.pi/10
        ),
)

# %%
rbend = RBend(
        name = "rb",
        length = 5.0,
        BendP=BendParameters(
            rho_ref=math.pi/10
        ),
        MagneticMultipoleP=MagneticMultipoleParameters(
            Kn1=1e-5,
        ),
)

# %%
sext1 = Sextupole(
        name="sext1",
        length = 0.5,
        MagneticMultipoleP=MagneticMultipoleParameters(
            Kn2=0.5,
        ),
)
# Out:
# /opt/anaconda3/envs/pals-python/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3699: UserWarning: The Sextupole element is marked as 'Under Construction' in the PALS standard. Please refer to the PALS documentation for current status and limitations.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sext2 = Sextupole(
        name="sext2",
        length = 0.5,
        MagneticMultipoleP=MagneticMultipoleParameters(
            Kn2=-0.5,
        ),
)

# %%
quad1 = Quadrupole(
        name="quad1",
        length=1.0,
        MagneticMultipoleP=MagneticMultipoleParameters(
            Kn1=1.0,
        ),
    )

# %%
drift2 = Drift(
        name="drift2",
        length=0.5,
    )

# %%
quad2 = Quadrupole(
        name="quad2",
        length=1.0,
        MagneticMultipoleP=MagneticMultipoleParameters(
            Kn1=-1.0,
        ),
    )

# %%
drift3 = Drift(
        name="drift3",
        length=0.5,
    )

# %%
kicker1 = Kicker(
          name="kicker1",
          length=0.01,
          MagneticMultipoleP=MagneticMultipoleParameters(
            Kn1=0.,
        ),
    )
# Out:
# /opt/anaconda3/envs/pals-python/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3699: UserWarning: The Kicker element is marked as 'Under Construction' in the PALS standard. Please refer to the PALS documentation for current status and limitations.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
kicker2 = Kicker(
          name="kicker2",
          length=0.01,
          MagneticMultipoleP=MagneticMultipoleParameters(
            Ks1=0.,
        ),
    )

# %%
drift4 = Drift(
        name="drift4",
        length=1.,
    )

# %%
# Create line with all elements
line = BeamLine(
        name="fodo_cell",
        line=[
            drift1,
            quad1,
            kicker1,
            drift1,
            sext1,
            drift4,
            sbend,
            drift4,
            drift2,
            quad2,
            kicker2,
            drift3,
            sext2
        ],
    )

# %%
print(line)
# Out:
# kind='BeamLine' name='fodo_cell' ApertureP=None BodyShiftP=None FloorP=None MetaP=None ReferenceP=None ReferenceChangeP=None TrackingP=None line=[Drift(kind='Drift', name='drift1', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=0.25), Quadrupole(kind='Quadrupole', name='quad1', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=1.0, ElectricMultipoleP=None, MagneticMultipoleP=MagneticMultipoleParameters(Kn1=1.0)), Kicker(kind='Kicker', name='kicker1', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=0.01, ElectricMultipoleP=None, MagneticMultipoleP=MagneticMultipoleParameters(Kn1=0.0)), Drift(kind='Drift', name='drift1', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=0.25), Sextupole(kind='Sextupole', name='sext1', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=0.5, ElectricMultipoleP=None, MagneticMultipoleP=MagneticMultipoleParameters(Kn2=0.5)), Drift(kind='Drift', name='drift4', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=1.0), SBend(kind='SBend', name='sb', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=5.0, BendP=BendParameters(rho_ref=0.3141592653589793, bend_field_ref=0.0, e1=0.0, e2=0.0, e1_rect=0.0, e2_rect=0.0, edge_int1=0.0, edge_int2=0.0, g_ref=0.0, h1=0.0, h2=0.0, L_chord=0.0, L_sagitta=0.0, tilt_ref=0.0), ElectricMultipoleP=None, MagneticMultipoleP=None), Drift(kind='Drift', name='drift4', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=1.0), Drift(kind='Drift', name='drift2', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=0.5), Quadrupole(kind='Quadrupole', name='quad2', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=1.0, ElectricMultipoleP=None, MagneticMultipoleP=MagneticMultipoleParameters(Kn1=-1.0)), Kicker(kind='Kicker', name='kicker2', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=0.01, ElectricMultipoleP=None, MagneticMultipoleP=MagneticMultipoleParameters(Ks1=0.0)), Drift(kind='Drift', name='drift3', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=0.5), Sextupole(kind='Sextupole', name='sext2', ApertureP=None, BodyShiftP=None, FloorP=None, MetaP=None, ReferenceP=None, ReferenceChangeP=None, TrackingP=None, length=0.5, ElectricMultipoleP=None, MagneticMultipoleP=MagneticMultipoleParameters(Kn2=-0.5))]

# %%
# Serialize to YAML
yaml_data = yaml.dump(line.model_dump(), default_flow_style=False)

# %%
print(yaml_data)
# Out:
# fodo_cell:
#   kind: BeamLine
#   line:
#   - drift1:
#       kind: Drift
#       length: 0.25
#   - quad1:
#       MagneticMultipoleP:
#         Kn1: 1.0
#       kind: Quadrupole
#       length: 1.0
#   - kicker1:
#       MagneticMultipoleP:
#         Kn1: 0.0
#       kind: Kicker
#       length: 0.01
#   - drift1:
#       kind: Drift
#       length: 0.25
#   - sext1:
#       MagneticMultipoleP:
#         Kn2: 0.5
#       kind: Sextupole
#       length: 0.5
#   - drift4:
#       kind: Drift
#       length: 1.0
#   - sb:
#       BendP:
#         L_chord: 0.0
#         L_sagitta: 0.0
#         bend_field_ref: 0.0
#         e1: 0.0
#         e1_rect: 0.0
#         e2: 0.0
#         e2_rect: 0.0
#         edge_int1: 0.0
#         edge_int2: 0.0
#         g_ref: 0.0
#         h1: 0.0
#         h2: 0.0
#         rho_ref: 0.3141592653589793
#         tilt_ref: 0.0
#       kind: SBend
#       length: 5.0
#   - drift4:
#       kind: Drift
#       length: 1.0
#   - drift2:
#       kind: Drift
#       length: 0.5
#   - quad2:
#       MagneticMultipoleP:
#         Kn1: -1.0
#       kind: Quadrupole
#       length: 1.0
#   - kicker2:
#       MagneticMultipoleP:
#         Ks1: 0.0
#       kind: Kicker
#       length: 0.01
#   - drift3:
#       kind: Drift
#       length: 0.5
#   - sext2:
#       MagneticMultipoleP:
#         Kn2: -0.5
#       kind: Sextupole
#       length: 0.5

# %%
# Write YAML data to file
yaml_file = "examples_fodo.yaml"

with open(yaml_file, "w") as file:
    file.write(yaml_data)

# %%
# Read YAML data from file
with open(yaml_file, "r") as file:
    yaml_data = yaml.safe_load(file)

# %%
# Parse YAML data
loaded_line = BeamLine(**yaml_data)

# %%
# Validate loaded data
line == loaded_line
# Out:
# True

# %%
# Serialize to JSON
json_data = json.dumps(line.model_dump(), sort_keys=True, indent=2)

# %%
# Write JSON data to file
json_file = "examples_fodo.json"

with open(json_file, "w") as file:
    file.write(json_data)

# %%
# Read JSON data from file
with open(json_file, "r") as file:
    json_data = json.loads(file.read())

# %%
# Parse JSON data
loaded_line = BeamLine(**json_data)

# %%
# Validate loaded data
line == loaded_line
# Out:
# True
